# %%
import sklearn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
print("import successful")
# Out:
# import successful

# %%
from sklearn import datasets

# %%
rawDF = pd.read_csv("SUMS Tool Data.csv")
rawDF.head()
# Out:
#   Billing Period      Charge Type  User Name First Last  \
# 0       2022 - 5  Equipment Usage                   NaN
# 1       2022 - 5  Equipment Usage                   NaN
# 2       2022 - 3  Equipment Usage                   NaN
# 3       2022 - 3  Equipment Usage                   NaN
# 4       2022 - 5  Equipment Usage                   NaN
#
#    User Name Last Comma First  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#                                  Research Group Name           Tool Name  \
# 0  GWW ME School NoCharge(Amit Jariwala - ajariwa...  Hub - General User
# 1  GWW ME School NoCharge(Amit Jariwala - ajariwa...  Hub - General User
# 2  GWW ME School NoCharge(Amit Jariwala - ajariwa...  Hub - General User
# 3  GWW ME School NoCharge(Amit Jariwala - ajariwa...  Hub - General User
# ...

# %%
targetDF = rawDF[['Tool Name']]
targetDF
# Out:
#                Tool Name
# 0     Hub - General User
# 1     Hub - General User
# 2     Hub - General User
# 3     Hub - General User
# 4     Hub - General User
# ...                  ...
# 6315  Hub - General User
# 6316  Hub - General User
# 6317  Hub - General User
# 6318  Hub - General User
# 6319  Hub - General User
#
# [6320 rows x 1 columns]

# %%
dataDF = rawDF[['Number Of Actual Hours']]
dataDF

#dataDF = rawDF[['Duration', 'Start Date Time', 'End Date Time', 'Number Of Actual Hours']]
# Out:
#       Number Of Actual Hours
# 0                  18.258333
# 1                  17.860833
# 2                  12.454444
# 3                  12.440000
# 4                  12.355000
# ...                      ...
# 6315                0.000000
# 6316                0.000000
# 6317                0.000000
# 6318                0.000000
# 6319                0.000000
#
# [6320 rows x 1 columns]

# %%
dataDF.isna().sum() #shows missing data
# Out:
# Number Of Actual Hours    0
# dtype: int64

# %%
import pandas as pd
import re

# %%
data = pd.read_csv('SUMS Tool Data.csv')
data
# Out:
#      Billing Period      Charge Type  User Name First Last  \
# 0          2022 - 5  Equipment Usage                   NaN
# 1          2022 - 5  Equipment Usage                   NaN
# 2          2022 - 3  Equipment Usage                   NaN
# 3          2022 - 3  Equipment Usage                   NaN
# 4          2022 - 5  Equipment Usage                   NaN
# ...             ...              ...                   ...
# 6315       2022 - 4  Equipment Usage                   NaN
# 6316       2022 - 4  Equipment Usage                   NaN
# 6317       2022 - 4  Equipment Usage                   NaN
# 6318       2022 - 4  Equipment Usage                   NaN
# 6319       2022 - 4  Equipment Usage                   NaN
#
#       User Name Last Comma First  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# ...

# %%
dataDF_ = dataDF.replace('[^\d.]', '', regex=True).astype(float)
dataDF_
# Out:
#       Number Of Actual Hours
# 0                  18.258333
# 1                  17.860833
# 2                  12.454444
# 3                  12.440000
# 4                  12.355000
# ...                      ...
# 6315                0.000000
# 6316                0.000000
# 6317                0.000000
# 6318                0.000000
# 6319                0.000000
#
# [6320 rows x 1 columns]

# %%
dataDF.dtypes
# Out:
# Number Of Actual Hours    float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    dataDF, targetDF, test_size=0.05, shuffle=True   
)

print("shape of sample training data:", X_train.shape)
print("shape of sample testing data:", X_test.shape)
print("shape of target training data:", y_train.shape)
print("shape of target testing data:", y_test.shape)
# Out:
# shape of sample training data: (6004, 1)
# shape of sample testing data: (316, 1)
# shape of target training data: (6004, 1)
# shape of target testing data: (316, 1)

# %%
import datetime

x = datetime.datetime.now()
print(x)

#year-month-day hour:minute:second
# Out:
# 2022-07-25 02:18:21.338352

# %%
from sklearn.neural_network import MLPClassifier

nnModel = MLPClassifier()

nnModel.fit(X_train,y_train)
# Out:
# /Users/kwe/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# MLPClassifier()

# %% [markdown]
# NEURAL NET

# %%
from sklearn.metrics import accuracy_score

nnPrediction = nnModel.predict(X_test)

nnAccuracy = accuracy_score(y_test, nnPrediction)

nnAccuracy
# Out:
# 0.8639240506329114

# %% [markdown]
# from sklearn.metrics import confusion_matrix
# import seaborn as sn
# confusion_matrix = confusion_matrix(y_test, nnPrediction)
# fig, ax = plt.subplots(figsize=(10,10))
#
# sn.heatmap(confusion_matrix, annot=True, ax=ax, fmt='g',vmin=0)
# ax.set_ylabel("true label")
# ax.set_xlabel("predicted label")

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn import svm

svmModel = svm.SVC()

svmModel.fit(X_train, y_train.values.ravel())

svmPredictions = svmModel.predict(X_test)

svmAccuracy = accuracy_score(y_test, svmPredictions)

svmAccuracy
# Out:
# 0.8639240506329114

# %% [markdown]
# from sklearn.metrics import confusion_matrix
#
# confusion_matrix = confusion_matrix(y_test, svmPredictions)
# fig, ax = plt.subplots(figsize=(10,10))
#
# sn.heatmap(confusion_matrix, annot=True, ax=ax, fmt='g',vmin=0)
# ax.set_ylabel("true label")
# ax.set_xlabel("predicted label")

# %% [markdown]
# DECISION TREE

# %%
from sklearn import tree

treeModel = tree.DecisionTreeClassifier()

treeModel.fit(X_train, y_train)

treePredictions = treeModel.predict(X_test)

treeAccuracy = accuracy_score(y_test, treePredictions)

treeAccuracy
# Out:
# 0.7943037974683544

# %% [markdown]
# from sklearn.metrics import confusion_matrix
#
# confusion_matrix = confusion_matrix(y_test, treePredictions)
# fig, ax = plt.subplots(figsize=(10,10))
#
# sn.heatmap(confusion_matrix, annot=True, ax=ax, fmt='g',vmin=0)
# ax.set_ylabel("General Users")
# ax.set_xlabel("Month")
